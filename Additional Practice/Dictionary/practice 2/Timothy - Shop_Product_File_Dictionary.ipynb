# %% [markdown]
# # Practical Programming Question — File Processing and Dictionary
#
# ## Shop Product Information — 10 Marks
#
# A shop stores information about its products in a text file named **`product_info.txt`**.
# Each line contains `Product ID, Product Name, Price`, separated by commas.
#
# Example:
#
# ```text
# P001,Wireless Mouse,25.90
# P002,Keyboard,45.50
# P003,USB-C Cable,12.90
# P004,Webcam,59.90
# P005,Headphones,79.90
# ```
#
# Write a Python program to create a **shop list**. The shop list must be a **list of dictionaries**, where each dictionary represents one product and contains exactly three key-value pairs:
#
# - `"Product ID"` — product ID
# - `"Name"` — product name
# - `"Price"` — product price
#
# ### Tasks
#
# **(a)** Create an empty list called `shop`. Open and read `product_info.txt` one line at a time. **[2 marks]**
#
# **(b)** For each line, split the data into Product ID, Name and Price. Create a dictionary containing the three key-value pairs and append the dictionary to the `shop` list. **[5 marks]**
#
# **(c)** Display all products in `shop` in the following format. **[3 marks]**
#
# ```text
# Product ID: P001 | Name: Wireless Mouse | Price: $25.90
# Product ID: P002 | Name: Keyboard | Price: $45.50
# Product ID: P003 | Name: USB-C Cable | Price: $12.90
# Product ID: P004 | Name: Webcam | Price: $59.90
# Product ID: P005 | Name: Headphones | Price: $79.90
# ```
#
# ### Requirements
# - Read the product data from **`product_info.txt`**; do not hard-code the products.
# - Each product must be represented by a dictionary with exactly three keys: `"Product ID"`, `"Name"` and `"Price"`.
# - Store all product dictionaries in a list called `shop`.
# - Convert the price to an appropriate numeric data type.
# - Do not create a separate dictionary manually for each product.

# %%
# Write your Python program here.

# (a) Create an empty shop list and open product_info.txt.


# (b) Read each line, create a product dictionary and append it to shop.


# (c) Display all products in the required format.
